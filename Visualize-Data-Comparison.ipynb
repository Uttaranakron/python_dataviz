# %% [markdown]
# # รายได้เฉลี่ยต่อเดือนต่อครัวเรือน จำแนกตามภาค และจังหวัด พ.ศ. 2541 - 2558
# - เลือกบางจังหวัด
# - เปรียบเทียบรายได้
# - เปลี่ยนชื่อโดยใช้ tick เปลี่ยนชื่อ
# - สร้างกราฟเปรียบเทียบ ของปี 2541 และ 2558
# - สร้างกราฟให้ข้อมูลซ้อนกัน 2 แท่ง 4 สี

# %%
import pandas as pd
from matplotlib  import pyplot as plt

# %%
df = pd.read_excel('C:\\Users\\ASUS\\Documents\\python\\python_dataviz\\income.xls',header = 3)
df
# Out:
#        ภาค และจังหวัด                                         Unnamed: 1  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2     ทั่วราชอาณาจักร                                                NaN
# 3            ตอนพิเศษ                                                NaN
# 4       กรุงเทพมหานคร                                                NaN
# ..                ...                                                ...
# 84           นราธิวาส                                                NaN
# 85                NaN                                                NaN
# 86                NaN                                                NaN
# 87             ที่มา:  การสำรวจภาวะเศรษฐกิจและสังคมของครัวเรือน  สำนั...
# 88            Source:  The Household Socio - Economic Survey, Nationa...
#
#        2541     2543     2545     2547     2549     2550     2552     2554  \
# ...

# %% [markdown]
# ต่อไปคือตัดเอาบางจังหวัดเท่านั้น

# %%
greaterbangkok = df.iloc[7:11,:]
greaterbangkok
# Out:
#          ภาค และจังหวัด Unnamed: 1     2541     2543     2545     2547  \
# 7              ปทุมธานี        NaN  21793.0  19282.0  22838.0  21530.0
# 8               ภาคกลาง        NaN  12643.0  13012.0  14128.0  16355.0
# 9       พระนครศรีอยุธยา        NaN  12918.0  14904.0  13319.0  14980.0
# 10              อ่างทอง        NaN  10878.0  12544.0  11653.0  12855.0
#
#        2549     2550     2552     2554     2556          2558  \
# 7   25143.0  26107.0  26686.0  21615.5  33461.3  41056.900000
# 8   19279.0  18932.0  20960.0  20821.8  26114.0  26601.069581
# 9   19676.0  21676.0  25820.0  22301.7  26481.5  28379.400000
# 10  18300.0  17704.0  25506.0  21139.9  28641.3  23350.600000
#
#              Region and province
# 7                   Pathum Thani
# 8                 Central Region
# 9       Phra Nakhon Si Ayutthaya
# 10                     Ang Thong

# %% [markdown]
# - ต่อไปจะเทียบรายได้ของ 4 จังหวัดนี้

# %%
greaterbangkok = df.iloc[4:8,:]
greaterbangkok
# Out:
#       ภาค และจังหวัด Unnamed: 1     2541     2543     2545     2547     2549  \
# 4      กรุงเทพมหานคร        NaN  26054.0  26909.0  29589.0  29843.0  36658.0
# 5        สมุทรปราการ        NaN  18100.0  15745.0  19680.0  19946.0  20382.0
# 6            นนทบุรี        NaN  24211.0  24566.0  29119.0  26658.0  31152.0
# 7           ปทุมธานี        NaN  21793.0  19282.0  22838.0  21530.0  25143.0
#
#       2550     2552     2554     2556     2558 Region and province
# 4  39020.0  42380.0  48951.0  49190.8  45571.7             Bangkok
# 5  21302.0  23359.0  23797.9  29575.3  25457.2        Samut Prakan
# 6  32743.0  34626.0  35119.7  30663.6  36884.0          Nonthaburi
# 7  26107.0  26686.0  21615.5  33461.3  41056.9        Pathum Thani

# %% [markdown]
# # 1. Barchat (กราฟแท่ง)
# ## สร้างกราฟแท่งเปรียบเทียบรายได้ในปี 2541 ของจังหวัดกรุงเทพและปริมณฑล

# %% [markdown]
# https://matplotlib.org/3.1.3/api/_as_gen/matplotlib.pyplot.scatter.html

# %%
greaterbangkok = df.iloc[4:8,:]
greaterbangkok
# Out:
#       ภาค และจังหวัด Unnamed: 1     2541     2543     2545     2547     2549  \
# 4      กรุงเทพมหานคร        NaN  26054.0  26909.0  29589.0  29843.0  36658.0
# 5        สมุทรปราการ        NaN  18100.0  15745.0  19680.0  19946.0  20382.0
# 6            นนทบุรี        NaN  24211.0  24566.0  29119.0  26658.0  31152.0
# 7           ปทุมธานี        NaN  21793.0  19282.0  22838.0  21530.0  25143.0
#
#       2550     2552     2554     2556     2558 Region and province
# 4  39020.0  42380.0  48951.0  49190.8  45571.7             Bangkok
# 5  21302.0  23359.0  23797.9  29575.3  25457.2        Samut Prakan
# 6  32743.0  34626.0  35119.7  30663.6  36884.0          Nonthaburi
# 7  26107.0  26686.0  21615.5  33461.3  41056.9        Pathum Thani

# %% [markdown]
# - ข้อสอบทำให้ชื่อภาษาไทยขึ้นให้ได้่

# %%
plt.bar([1,2,3,4],greaterbangkok.iloc[:,2])  #กราฟมี 4 แท่ง โดยเลือกรายได้ปี 41
plt.title('Barchart comparing average monthly incom of provinces in greater Bangkok in 2541')#ชื่อเรื่องกราฟ
plt.xlabel('Provinces') # ชื่อแกน x
plt.ylabel('Income Baht/Moth/Household') # ชื่อแกน y
# Out:
# Text(0, 0.5, 'Income Baht/Moth/Household')

# %% [markdown]
# # add tick label
# - tick เปลี่ยนชื่อ

# %%
plt.bar([1,2,3,4],greaterbangkok.iloc[:,2],tick_label=greaterbangkok.iloc[:,-1])  # เลือกทุกแถว 
plt.title('Barchart comparing average monthly incom of provinces in greater Bangkok in 2541')# ชื่อเรื่องกราฟภาษาอังกฤษ
plt.xlabel('Provinces')
plt.ylabel('Income Baht/Moth/Household')
# Out:
# Text(0, 0.5, 'Income Baht/Moth/Household')

# %% [markdown]
#  add tick label ตอนสอบให้ตั้งชื่อเป็นภาษาไทย "กราฟเปรียบเทียบรายได้ปี 2541 ของจังหวัดกรุงเทพและปริมณฑล"

# %%
plt.bar([1,2,3,4],greaterbangkok.iloc[:,2],tick_label=greaterbangkok.iloc[:,-1])  # เลือกทุกแถว 
plt.title(u'กราฟเปรียบเทียบรายได้ปี 2541 ของจังหวัดกรุงเทพและปริมณฑล',fontname='Tahoma',fontsize='13')# ชื่อเรื่องกราฟภาษาไทย
plt.xlabel('Provinces')
plt.ylabel('Income Baht/Moth/Household')
# Out:
# Text(0, 0.5, 'Income Baht/Moth/Household')

# %% [markdown]
# # compare different years
# กราฟเปรียบเทียบรายได้ในแต่ละปี

# %%
plt.bar([1-(0.35/2),2-(0.35/2),3-(0.35/2),4-(0.35/2)],greaterbangkok.iloc[:,-2],width=0.35,tick_label =greaterbangkok.iloc[:,-1],color = 'r',label = '2558',align = 'edge')
plt.bar([1+(0.35/2),2+(0.35/2),3+(0.35/2),4+(0.35/2)],greaterbangkok.iloc[:,2],width=0.35,tick_label =greaterbangkok.iloc[:,-1],color = 'y',label = '2541',align = 'edge')
##align ใช้คำสั่งให้ Label ตรงกลางกราฟทั้ง 2 แท่ง
plt.title(u'กราฟเปรียบเทียบรายได้ปี 2541 ของจังหวัดกรุงเทพและปริมณฑล',fontname='Tahoma',fontsize='13')
plt.legend(loc = 0) ##บอกว่าแท่งไหนคือปีไหน 
plt.ylabel('income Bath/Month/Household')
# Out:
# Text(0, 0.5, 'income Bath/Month/Household')

# %% [markdown]
# #   Stacked BarChart
# กราฟแท่งแบบต่อกันเป็นชั้น
# - Create new Table

# %%
##Create Data Frame ส่วนมากจะเป็นข้อมูลการขายสินค้าที่นำมาทำ Stacked BarChart
seledata = pd.DataFrame([{'North':20,'East' :10,'West':90,'South':120},
                       {'North':220,'East' :20,'West':50,'South':90}])
seledata
# Out:
#    North  East  West  South
# 0     20    10    90    120
# 1    220    20    50     90

# %% [markdown]
# - stacked Barchart 2 ชั้น

# %%
plt.bar([1,2],seledata.iloc[:,0],tick_label =['Company A','Company B'])
plt.bar([1,2],seledata.iloc[:,1],bottom = seledata.iloc[:,0],tick_label =['Company A','Company B']) 
plt.bar([1,2],seledata.iloc[:,2],bottom = seledata.iloc[:,0]+seledata.iloc[:,1],tick_label =['Company A','Company B']) 
plt.bar([1,2],seledata.iloc[:,3],bottom = seledata.iloc[:,0]+seledata.iloc[:,1]+seledata.iloc[:,2],tick_label =['Company A','Company B'])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # 2. Histogram (กราฟความถี่)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
## Fixing random state for reproducibility
np.random.seed(19680801)
## seed คือ Run กี่ครั้งก็จะได้ค่า Random เหมือนเดิมทุกครั้ง

# %%
np.random.randn()
# Out:
# 1.0493043103878812

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# %%
plt.hist(x, 50, density=True, facecolor='r', alpha=0.75);

# %% [markdown]
# # 3. Tree Map

# %%
import squarify

# %%
## ตัวเลขปริมาณ คำนวณว่าสี่เหลี่ยมเล็กนับเป็นกี่เปอร์เซนของสี่เหี่ยมใหญ่
volume = [350, 220, 170, 150, 50]

# %%
squarify.plot(sizes=volume)

# %%
labels = ['Liquid\n volume: 350k', 'Savoury\n volume: 220k',
              'Sugar\n volume: 170k', 'Frozen\n volume: 150k',
              'Non-food\n volume: 50k']

color_list = ['#ea3033', '#a432ff', '#ffe9a3',
                  '#775aac', '#d35158', '#202450']
## \n คือการขึ้นบรรทัดใหม่
##อ้างถึงที่เป็นตัวเลขฐาน 16

# %%
squarify.plot(sizes=volume, label=labels,
                      color=color_list, alpha=0.7)
## alpha คือความโปร่งใส

# %% [markdown]
# # 4. Radar chart
# เปรียบเทียบ 2 อย่าง ว่าอันไหนดีกว่ากัน

# %%
from math import pi

# %%
pi
# Out:
# 3.141592653589793

# %%
df= pd.DataFrame([{'Client_id':'c1','cheese':2,'beer':2,'chicken':5,'bread':4,'coffee':2},
                                            {'Client_id':'c2','cheese':5,'beer':1,'chicken':3,'bread':3,'coffee':3},
                                            {'Client_id':'c3','cheese':4,'beer':3,'chicken':3,'bread':2,'coffee':5},
                                            {'Client_id':'c4','cheese':3,'beer':5,'chicken':4,'bread':1,'coffee':3}])

# %%
df
# Out:
#   Client_id  cheese  beer  chicken  bread  coffee
# 0        c1       2     2        5      4       2
# 1        c2       5     1        3      3       3
# 2        c3       4     3        3      2       5
# 3        c4       3     5        4      1       3

# %%
categories = list(df)[1:]

# %%
categories
# Out:
# ['cheese', 'beer', 'chicken', 'bread', 'coffee']

# %% [markdown]
# ตัวอย่าง 1

# %%
values = df.mean().values.flatten().tolist()
values += values[:1] # repeat the first value to close the circular graph
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

# %%
#เตรียมพื้นที่ในการ plot 
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)

ax.plot(angles, values, linewidth=1, linestyle='solid')
ax.fill(angles, values, 'skyblue', alpha=0.4)

plt.show()

# %% [markdown]
# ตัวอย่าง 2

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)

# part 1
val_c1 = df.loc[0].drop('Client_id').values.flatten().tolist()
val_c1 += val_c1[:1]
ax.plot(angles, val_c1, linewidth=1,
        linestyle='solid', label='Client c1')
ax.fill(angles, val_c1, 'skyblue', alpha=0.4)

# part 2
val_c2=df.loc[1].drop('Client_id').values.flatten().tolist()
val_c2 += val_c2[:1]
ax.plot(angles, val_c2, linewidth=1,
        linestyle='solid', label='Client c2')
ax.fill(angles, val_c2, 'lightpink', alpha=0.4)
 
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
plt.show()

# %% [markdown]
# ## 5. Word cloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
df =  pd.read_csv('C:\\Users\\ASUS\\Documents\\python\\python_dataviz\\message.csv')

# %%
df
# Out:
#      Unnamed: 0                       PartitionKey      RowKey  \
# 0             0  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168228
# 1             1  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168251
# 2             2  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168285
# 3             3  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168308
# 4             4  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168312
# ..          ...                                ...         ...
# 963         963  Uf9cb1d388c137ce49307370e6e9120e1  1582631314
# 964         964  Ufd3d31906486863b4dabc0b563c7802a  1582604220
# 965         965  Ufd3d31906486863b4dabc0b563c7802a  1582604226
# 966         966  Ufd3d31906486863b4dabc0b563c7802a  1582604239
# 967         967  Ufd3d31906486863b4dabc0b563c7802a  1582604245
#
#                             Timestamp                     message  \
# 0    2020-02-20 03:10:29.464192+00:00                       Hello
# 1    2020-02-20 03:10:52.853726+00:00  img : not a parasite image
# ...

# %% [markdown]
# ตัวอย่าง 1 Basic word cloud

# %%
from wordcloud import WordCloud
from PIL import Image

# %%
text = ('Data science is an interdisciplinary field that uses scientific \
            methods, processes, algorithms and systems to extract knowledge and insights \
            from data in various forms, both structured and unstructured, similar to data \
            mining. Data science is a concept to unify statistics, data analysis, machine \
            learning and their related methods in order to understand and analyze actual \
            phenomena with data. It employs techniques and theories drawn from many fields \
            within the context of mathematics, statistics, information science, and \
            computer science. Turing award winner Jim Gray imagined data science as a \
            fourth paradigm of science (empirical, theoretical, computational and now \
            data-driven) and asserted that everything about science is changing because of \
            the impact of information technology and the data deluge. In 2012, when Harvard \
            Business Review called it The Sexiest Job of the 21st Century, the term data \
            science became a buzzword. It is now often used interchangeably with earlier \
            concepts like business analytics, business intelligence, predictive modeling, \
            and statistics. Even the suggestion that data science is sexy was paraphrasing \
            Hans Rosling, featured in a 2011 BBC documentary with the quote, Statistics is \
            now the sexiest subject around. Nate Silver referred to data science as a sexed \
            up term for statistics. In many cases, earlier approaches and solutions are now \
            simply rebranded as data science to be more attractive, which can cause the \
            term to become dilute beyond usefulness. While many university programs now \
            offer a data science degree, there exists no consensus on a definition or \
            suitable curriculum contents. To its discredit, however, many data-science and \
            big-data projects fail to deliver useful results, often as a result of poor \
            management and utilization of resources')

wordcloud = WordCloud(width=1280, height=853, margin=0,
                      colormap='Blues').generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# # Homework

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\ASUS\\Documents\\python\\python_dataviz\\message.csv')
df
# Out:
#      Unnamed: 0                       PartitionKey      RowKey  \
# 0             0  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168228
# 1             1  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168251
# 2             2  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168285
# 3             3  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168308
# 4             4  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168312
# ..          ...                                ...         ...
# 963         963  Uf9cb1d388c137ce49307370e6e9120e1  1582631314
# 964         964  Ufd3d31906486863b4dabc0b563c7802a  1582604220
# 965         965  Ufd3d31906486863b4dabc0b563c7802a  1582604226
# 966         966  Ufd3d31906486863b4dabc0b563c7802a  1582604239
# 967         967  Ufd3d31906486863b4dabc0b563c7802a  1582604245
#
#                             Timestamp                     message  \
# 0    2020-02-20 03:10:29.464192+00:00                       Hello
# 1    2020-02-20 03:10:52.853726+00:00  img : not a parasite image
# ...

# %%
message = df.iloc[:,4]

# %%
message
# Out:
# 0                           Hello
# 1      img : not a parasite image
# 2                 img : Trichuris
# 3                   img : Ascaris
# 4                           อาการ
#                   ...
# 963                           บาย
# 964                       Dee kub
# 965                         ดีคับ
# 966                    สวัสดีครับ
# 967                            Hi
# Name: message, Length: 968, dtype: object

# %%
message[0]
# Out:
# 'Hello'

# %%
text = ''

# %%
for i in range(len(message)):
    text += message[i]

# %%
text
# Out:
# 'Helloimg : not a parasite imageimg : Trichurisimg : Ascarisอาการชนิดของไข่พยาธิรู้ได้อย่างไรว่าติดพยาธิหวัดดีจ้าimg : Trichurisหวัดดีจ้าimg : hookwormsไข่พยาธิชื่อว่าอะไรไข่พยาธิชื่อว่าอะไรไข่พยาธิกลุ่มใดอาการรู้ได้อย่างไรว่าติดพยาธิimg : Trichurisimg : Trichurisimg : hookwormsลักษณะเด่นของไข่พยาธิimg : Trichurisหวัดดีจ้าาimg : not a parasite imageสวัสดีค่ะHelloจากรูปภาพเป็นไข่พยาธิชนิดใดimg : Taeniaimg : Trichurisอาการimg : OVลักษณะเด่นของไข่พยาธิไข่พยาธิชื่อว่าอะไรวิธีป้องกันHelloimg : not a parasite imageimg : Trichurisอาการimg : EnterobiusHelloimg : Taeniaimg : Ascarisimg : not a parasite imageimg : Taeniaรู้ได้อย่างไรว่าติดพยาธิลักษณะเด่นของไข่พยาธิลักษณะทั่วไปตัวเต็มวัยติดต่อสู่คนได้อย่างไรตัวเต็มวัยขนาดเท่าไหร่ไข่พยาธิกลุ่มใดimg : OVรู้ได้อย่างไรว่าติดพยาธิลักษณะเด่นของไข่พยาธิimg : Trichurisดีสวัสดีimg : not a parasite imageimg : Taeniaimg : Ascarisรู้ได้อย่างไรว่าติดพยาธิอาการชนิดของไข่พยาธิimg : Trichurisimg : Ascarisimg : Trichurisชนิดของไข่พยาธิลักษณะเด่นของไข่พยาธิไข่พย
# ...

# %%
wordcloud = WordCloud(width=1280, height=853, margin=0,
                      colormap='Blues', font_step=4).generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.margins(x=0, y=0)

# %% [markdown]
# # สร้าง Word Cloud เป็นภาษาไทย

# %% [markdown]
# กำหนดตัวอักษร

# %%
path ='C:\\Users\\ASUS\\Documents\\python\\python_dataviz\\THSarabunNew Bold.ttf'

# %%
regexp = r"[ก-๙a-zA-Z']+"

# %%
wordcloud = WordCloud(
                      font_path=path, 
                      relative_scaling = 0.3,
                      min_font_size=1,
                      background_color="white",
                      width=1024,
                      height=768,
                      max_words=2000, 
                      colormap='plasma', 
                      scale=3,
                      font_step=4,
                    #   contour_width=3, 
                    #   contour_color='steelblue', 
                      collocations=False,
                      regexp=regexp,
                      margin=2
                      ).generate(text)

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 12))
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis("off")
fig.show()
# Out:
# C:\Users\ASUS\Miniconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.
