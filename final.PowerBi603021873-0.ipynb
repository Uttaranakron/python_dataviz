# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('C:\\Users\\acer\Desktop\\Basic programing\\2019_nCoV_data.csv')

# %%
data
# Out:
#        Sno                 Date   Province/State Country          Last Update  \
# 0        1  01/22/2020 12:00:00            Anhui   China  01/22/2020 12:00:00
# 1        2  01/22/2020 12:00:00          Beijing   China  01/22/2020 12:00:00
# 2        3  01/22/2020 12:00:00        Chongqing   China  01/22/2020 12:00:00
# 3        4  01/22/2020 12:00:00           Fujian   China  01/22/2020 12:00:00
# 4        5  01/22/2020 12:00:00            Gansu   China  01/22/2020 12:00:00
# ...    ...                  ...              ...     ...                  ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI      US  2020-02-05T21:53:02
# 1715  1716  02/17/2020 22:00:00       Orange, CA      US  2020-02-01T19:53:03
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX      US  2020-02-13T18:53:02
# 1717  1718  02/17/2020 22:00:00      Seattle, WA      US  2020-02-09T07:03:04
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ      US  2020-02-01T19:43:03
#
#       Confirmed  Deaths  Recovered
# 0             1       0          0
# 1            14       0          0
# 2             6       0          0
# 3             1       0          0
# 4             0       0          0
# ...         ...     ...        ...
# 1714          1       0          0
# 1715          1       0          0
# 1716          1       0          0
# 1717          1       0          1
# 1718          1       0          0
#
# [1719 rows x 8 columns]

# %%
data.isnull().any()
# Out:
# Sno               False
# Date              False
# Province/State     True
# Country           False
# Last Update       False
# Confirmed         False
# Deaths            False
# Recovered         False
# dtype: bool

# %%
data1=data.dropna()

# %%
data1
# Out:
#        Sno                 Date   Province/State Country          Last Update  \
# 0        1  01/22/2020 12:00:00            Anhui   China  01/22/2020 12:00:00
# 1        2  01/22/2020 12:00:00          Beijing   China  01/22/2020 12:00:00
# 2        3  01/22/2020 12:00:00        Chongqing   China  01/22/2020 12:00:00
# 3        4  01/22/2020 12:00:00           Fujian   China  01/22/2020 12:00:00
# 4        5  01/22/2020 12:00:00            Gansu   China  01/22/2020 12:00:00
# ...    ...                  ...              ...     ...                  ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI      US  2020-02-05T21:53:02
# 1715  1716  02/17/2020 22:00:00       Orange, CA      US  2020-02-01T19:53:03
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX      US  2020-02-13T18:53:02
# 1717  1718  02/17/2020 22:00:00      Seattle, WA      US  2020-02-09T07:03:04
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ      US  2020-02-01T19:43:03
#
#       Confirmed  Deaths  Recovered
# 0             1       0          0
# 1            14       0          0
# 2             6       0          0
# 3             1       0          0
# 4             0       0          0
# ...         ...     ...        ...
# 1714          1       0          0
# 1715          1       0          0
# 1716          1       0          0
# 1717          1       0          1
# 1718          1       0          0
#
# [1257 rows x 8 columns]

# %%
data_final=data1.groupby('Country').max().reset_index()

# %%
data_final
# Out:
#           Country   Sno                 Date                Province/State  \
# 0       Australia  1696  02/17/2020 22:00:00                      Victoria
# 1          Canada  1706  02/17/2020 22:00:00                   Toronto, ON
# 2           China    35  01/22/2020 12:00:00                      Zhejiang
# 3         Germany   488  01/31/2020 19:00:00                       Bavaria
# 4       Hong Kong  1677  02/17/2020 22:00:00                     Hong Kong
# 5           Macau  1686  02/17/2020 22:00:00                         Macau
# 6  Mainland China  1709  02/17/2020 22:00:00                      Zhejiang
# 7          Others  1657  02/17/2020 22:00:00  Diamond Princess cruise ship
# 8          Taiwan  1681  02/17/2020 22:00:00                        Taiwan
# 9              US  1719  02/17/2020 22:00:00                    Washington
#
#            Last Update  Confirmed  Deaths  Recovered
# 0  2020-02-17T08:13:09          5       0          4
# 1  2020-02-17T08:03:07          5       0          1
# 2  01/22/2020 12:00:00        444       0          0
# 3  01/31/2020 19:00:00          7       0          0
# 4  2020-02-17T22:53:01         60       1          2
# 5  2020-02-16T12:03:06         10       0          5
# 6  2020-02-17T23:53:02      59989    1789       7862
# 7  2020-02-17T14:33:04        454       0          0
# 8  2020-02-17T15:43:02         22       1          2
# 9  2020-02-13T18:53:02          3       0          2

# %%
data_final['Province/State']=data_final['Province/State'].fillna('Other')
data_final
# Out:
#           Country   Sno                 Date                Province/State  \
# 0       Australia  1696  02/17/2020 22:00:00                      Victoria
# 1          Canada  1706  02/17/2020 22:00:00                   Toronto, ON
# 2           China    35  01/22/2020 12:00:00                      Zhejiang
# 3         Germany   488  01/31/2020 19:00:00                       Bavaria
# 4       Hong Kong  1677  02/17/2020 22:00:00                     Hong Kong
# 5           Macau  1686  02/17/2020 22:00:00                         Macau
# 6  Mainland China  1709  02/17/2020 22:00:00                      Zhejiang
# 7          Others  1657  02/17/2020 22:00:00  Diamond Princess cruise ship
# 8          Taiwan  1681  02/17/2020 22:00:00                        Taiwan
# 9              US  1719  02/17/2020 22:00:00                    Washington
#
#            Last Update  Confirmed  Deaths  Recovered
# 0  2020-02-17T08:13:09          5       0          4
# 1  2020-02-17T08:03:07          5       0          1
# 2  01/22/2020 12:00:00        444       0          0
# 3  01/31/2020 19:00:00          7       0          0
# 4  2020-02-17T22:53:01         60       1          2
# 5  2020-02-16T12:03:06         10       0          5
# 6  2020-02-17T23:53:02      59989    1789       7862
# 7  2020-02-17T14:33:04        454       0          0
# 8  2020-02-17T15:43:02         22       1          2
# 9  2020-02-13T18:53:02          3       0          2

# %%
data_final1 = data_final[data_final['Country']!='Mainland China']
data_final2 = data_final1[data_final1['Country']!='Brazil']
data_final3 = data_final2[data_final2['Country']!='Mexico']
data_final4 = data_final3[data_final3['Country']!='China']
data_final5 = data_final4[data_final4['Country']!='Others']

# %%
p= data_final5.groupby('Country').max().reset_index()
p
# Out:
#      Country   Sno                 Date Province/State          Last Update  \
# 0  Australia  1696  02/17/2020 22:00:00       Victoria  2020-02-17T08:13:09
# 1     Canada  1706  02/17/2020 22:00:00    Toronto, ON  2020-02-17T08:03:07
# 2    Germany   488  01/31/2020 19:00:00        Bavaria  01/31/2020 19:00:00
# 3  Hong Kong  1677  02/17/2020 22:00:00      Hong Kong  2020-02-17T22:53:01
# 4      Macau  1686  02/17/2020 22:00:00          Macau  2020-02-16T12:03:06
# 5     Taiwan  1681  02/17/2020 22:00:00         Taiwan  2020-02-17T15:43:02
# 6         US  1719  02/17/2020 22:00:00     Washington  2020-02-13T18:53:02
#
#    Confirmed  Deaths  Recovered
# 0          5       0          4
# 1          5       0          1
# 2          7       0          0
# 3         60       1          2
# 4         10       0          5
# 5         22       1          2
# 6          3       0          2

# %%
plt.bar(p.iloc[:,0],p.iloc[:,5],color = 'c')
plt.title(u'จำนวนผู้ติดเชื้อของแต่ละประเทศ',name='Angsana New',size='30')
plt.xlabel('Country',name='Angsana New',size='25')
plt.ylabel('Confirmed')
# Out:
# Text(0, 0.5, 'Confirmed')

# %%
plt.bar(p.iloc[:,0],p.iloc[:,6],color = 'r')
plt.title(u'จำนวนผู้ที่ตายของแต่ละประเทศ',name='Angsana New',size='30')
plt.xlabel('Country',name='Angsana New',size='25')
plt.ylabel('Deaths')
# Out:
# Text(0, 0.5, 'Deaths')

# %%
plt.bar(p.iloc[:,0],p.iloc[:,7],color = 'g')
plt.title(u'จำนวนผู้ที่รักษาหายของแต่ละประเทศ',name='Angsana New',size='30')
plt.xlabel('Country',name='Angsana New',size='25')
plt.ylabel('Recovered')
# Out:
# Text(0, 0.5, 'Recovered')

# %%
plt.bar(p.iloc[:,0],p.iloc[:,3],color = 'b')
plt.title(u'จำนวนจังหวัด/รัฐ ของแต่ละประเทศ',name='Angsana New',size='30')
plt.xlabel('Country',name='Angsana New',size='25')
plt.ylabel('Province/State')
# Out:
# Text(0, 0.5, 'Province/State')

# %%
import matplotlib.pyplot as plt 
dataset.plot(kind='bar', x='Province/State', y='Deaths', color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-75568f461601> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 dataset.plot(kind='bar', x='Province/State', y='Deaths', color='red')
#       3 plt.show()
#
# NameError: name 'dataset' is not defined

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import pandas as pd

# %%
data_final = pd.read_csv('C:\\Users\\acer\Desktop\\Basic programing\\2019_nCoV_data.csv') 
data_final
# Out:
#        Sno                 Date   Province/State Country          Last Update  \
# 0        1  01/22/2020 12:00:00            Anhui   China  01/22/2020 12:00:00
# 1        2  01/22/2020 12:00:00          Beijing   China  01/22/2020 12:00:00
# 2        3  01/22/2020 12:00:00        Chongqing   China  01/22/2020 12:00:00
# 3        4  01/22/2020 12:00:00           Fujian   China  01/22/2020 12:00:00
# 4        5  01/22/2020 12:00:00            Gansu   China  01/22/2020 12:00:00
# ...    ...                  ...              ...     ...                  ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI      US  2020-02-05T21:53:02
# 1715  1716  02/17/2020 22:00:00       Orange, CA      US  2020-02-01T19:53:03
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX      US  2020-02-13T18:53:02
# 1717  1718  02/17/2020 22:00:00      Seattle, WA      US  2020-02-09T07:03:04
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ      US  2020-02-01T19:43:03
#
#       Confirmed  Deaths  Recovered
# 0             1       0          0
# 1            14       0          0
# 2             6       0          0
# 3             1       0          0
# 4             0       0          0
# ...         ...     ...        ...
# 1714          1       0          0
# 1715          1       0          0
# 1716          1       0          0
# 1717          1       0          1
# 1718          1       0          0
#
# [1719 rows x 8 columns]

# %%
data_final = data_final.iloc[:,3]
data_final
# Out:
# 0       China
# 1       China
# 2       China
# 3       China
# 4       China
#         ...
# 1714       US
# 1715       US
# 1716       US
# 1717       US
# 1718       US
# Name: Country, Length: 1719, dtype: object

# %%
data_final[0]
# Out:
# 'China'

# %%
text = ''

# %%
for i in range(len(data_final)):
    text += data_final[i]

# %%
text
# Out:
# 'ChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaChinaUSChinaChinaChinaJapanThailandSouth KoreaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaHong KongMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMacauMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaTaiwanMainland ChinaMainland ChinaUSMainland ChinaMainland ChinaMainland ChinaJapanThailandSouth KoreaSingaporePhilippinesMalaysiaVietnamAustraliaMexicoBrazilMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaTaiwanMainland ChinaHong KongMacauMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaUSUSJapanThailandSouth KoreaSingaporeVietnamFranceMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaHong KongMainland ChinaMainland ChinaMainland ChinaTaiwanMacauMainland ChinaUSUSJapanThailandSouth KoreaSingaporeVietnamFranceAustraliaNepalMalaysiaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaHong KongMainland ChinaMainland ChinaMacauMainland ChinaMainland ChinaTaiwanMainland ChinaUSUSUSUSJapanThailandSouth KoreaSingaporeVietnamFranceAustraliaNepalMalaysiaCanadaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaHong KongMainland ChinaMainland ChinaMacauMainland ChinaTaiwanMainland ChinaUSUSUSUSJapanThailandSouth KoreaSingaporeVietnamFranceNepalMalaysiaCanadaCambodiaSri LankaIvory CoastAustraliaAustraliaGermanyMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaHong KongTaiwanMacauMainland ChinaUSUSUSUSJapanThailandSouth KoreaSingaporeVietnamFranceNepalMalaysiaCanadaCanadaCambodiaSri LankaAustraliaAustraliaGermanyMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaMainland ChinaHong KongTaiwanMacauMainland ChinaMainland ChinaUSUSUSUSJapanThailandSouth KoreaSingaporeVietnamFranceNepalMalaysiaCanadaCanadaCambodiaSri LankaAustraliaAustraliaAustraliaGermanyFinlandUnited Arab EmiratesMainl ...

# %%
wordcloud = WordCloud(width=1280, height=853, margin=0,
                      colormap='Blues', font_step=4).generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.margins(x=0, y=0)

# %%
path = 'C:\\Users\\acer\\Downloads\\THSarabunNew\\THSarabunNew Bold.ttf'

# %%
regexp = r"[ก-๙a-zA-Z']+"

# %%
wordcloud = WordCloud(
                      font_path=path, 
                      relative_scaling = 0.3,
                      min_font_size=1,
                      background_color="white",
                      width=1024,
                      height=768,
                      max_words=2000, 
                      colormap='plasma', 
                      scale=3,
                      font_step=4,
                    #   contour_width=3, 
                    #   contour_color='steelblue', 
                      collocations=False,
                      regexp=regexp,
                      margin=2
                      ).generate(text)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis("off")
fig.show()
# Out:
# C:\Users\acer\Miniconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.
